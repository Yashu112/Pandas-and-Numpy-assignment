# %% [markdown]
# # Bokeh

# %%
import bokeh.io
import bokeh.plotting 
bokeh.io.output_notebook()
from bokeh.plotting import figure, output_file, show
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p5141">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# Q1. How can you create a Bokeh plot using Python code?
#
# Ans. For creating bokeh plot, we first have to import bokeh.io, bokeh.plotting, figure, output_file and show. We call boleh.io.output_notebook to display plot in Jupyter notebook. Then, we create an html file which shows the output plot.
#
# The libraries have been imported in the above cell. Below is an example of creating a simple plot using bokeh:

# %%
import numpy as np
x = np.linspace(0,10,201)
y = np.tan(x)

output_file=('tan(x).html')
p = figure(title='Plot of tan(x)', width=500,height=500)
p.xaxis.axis_label='x'
p.yaxis.axis_label='tan(x)'
p.line(x,y)
show(p)
# Out:
#   <div id="ce0e83df-8e76-435a-9ec6-8b08c72c0e08" data-root-id="p5142" style="display: contents;"></div>

# %% [markdown]
# ![bokeh_plot.png](attachment:a5d92759-0c71-45aa-a292-28dad2a4a99d.png)

# %% [markdown]
# Q2. What are glyphs in Bokeh, and how can you add them to a Bokeh plot? Explain with an example.
#
# Ans. Glyph is a class of objects in Bokeh library. Glyphs are various types of visual shapes and objects which can be used to reperesent the data points in our plot. Various common glyphs can simply be added as a method of the figure object.
#
# Example is as shown:

# %%
#Solution-2
from bokeh.layouts import row

x=[1,2,3,4,]
y=[1,2,3,4,]

pl1 = figure(title='GLYPHS',width=250, height=250)
pl1.star(x,y,size=25)

pl2 = figure(title='GLYPHS', width=250, height=250)
pl2.annulus(x,y,inner_radius=.1, outer_radius=.2)

pl3 = figure(title='GLYPHS', width=250, height=250)
pl3.ellipse(x,y, width=.5, height=.2, color='red')

pl4 = figure(title='GLYPHS', width=250, height=250)
pl4.triangle(x,y, size=15, color='green')

show(row(pl1,pl2,pl3,pl4))
# Out:
#   <div id="a762b29c-d79f-48e2-927d-5a91e6d8a5ca" data-root-id="p3529" style="display: contents;"></div>

# %% [markdown]
# ![bokeh_plot (4).png](attachment:42b86a48-5a7a-4e80-b8d2-a396f451413f.png)![bokeh_plot (3).png](attachment:d036b10c-3405-4673-8854-7fb1aafa6906.png)![bokeh_plot (2).png](attachment:538ca5df-6e00-4388-8aed-d65a07f4a163.png)![bokeh_plot (1).png](attachment:6a5a90eb-d5ce-4d5a-a263-33642cfeb840.png)

# %% [markdown]
# Q3. How can you customize the appearance of a Bokeh plot, including the axes, title, and legend?
#
# Ans. First we create a plot object. Then using methods such as axes, title, etc, and attributes, we can customize the appearance of plot.
#
# An example using flowers dataset is shown as follows:

# %%
from bokeh.sampledata.iris import flowers
flowers.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
p=figure(title='flowers')
p.xaxis.axis_label = 'petal_length'
p.yaxis.axis_label = 'petal_width'
p.background_fill_color = 'pink'
p.circle(flowers['petal_length'], flowers['petal_width'], fill_color='red', legend_label = 'red points', size=10)
show(p)
# Out:
#   <div id="5814ed30-c5dd-4735-ae91-96d5800a346f" data-root-id="p4662" style="display: contents;"></div>

# %% [markdown]
# ![bokeh_plot (5).png](attachment:ca0943c6-4d66-40b5-b30f-64ca31816820.png)

# %% [markdown]
# Q4. What is a Bokeh server, and how can you use it to create interactive plots that can be updated in
# real time?
#
# Ans. Bokeh server is a component of Bokeh that allows us to create interactive web-applications which are connected to python code running at backend. This gives us the power of manipulating and updating the plot without having to change the python code. It is good for creating interactive visualizations, we based python apps, etc.

# %% [markdown]
# Q5. How can you embed a Bokeh plot into a web page or dashboard using Flask or Django?
#
# Ans. We can embed a Bokeh plot into a web page or dashboard using Flask in the following way

# %%
from flask import Flask, render_template
from bokeh.plotting import figure, show
from bokeh.resources import CDN
from bokeh.embed import file_html

app = Flask(__name__)

def create_bokeh_plot():
    plot = figure(title="Bokeh Plot Example", width=600, height=600)
    plot.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5])  
    html = file_html(plot, CDN, "my plot")
    return html

@app.route('/')
def index():
    plot = create_bokeh_plot()
    return plot

if __name__=="__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.1.5:5000
# Press CTRL+C to quit
# 192.168.1.5 - - [28/Aug/2023 16:04:26] "GET / HTTP/1.1" 200 -

# %% [markdown]
# The Screenshot of output of above code is as follows:

# %% [markdown]
# ![image.png](attachment:image.png)
